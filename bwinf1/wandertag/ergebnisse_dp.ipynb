# %% [raw]
# Beispiel 6:
# Anzahl Teilnehmer = 330
# Streckenlängen = [42834, 74810, 92920]
# CPU times: total: 45.7 s
# Wall time: 46 s
#
# Beispiel 7:
# Anzahl Teilnehmer = 551
# Streckenlängen = [39520, 76088, 91584]
# CPU times: total: 3min 16s
# Wall time: 3min 17s
